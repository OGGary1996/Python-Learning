# %%
from google.colab import drive
drive.mount("/content/drive/")
# Out:
# Mounted at /content/drive/

# %%
pwd
# Out:
# '/content'

# %%
ls
# Out:
# drive/  sample_data/

# %%
cd /content/drive/MyDrive/movielens/ml-32m/
# Out:
# /content/drive/MyDrive/movielens/ml-32m

# %%
ls
# Out:
# checksums.txt  links.csv  movies.csv  ratings.csv  README.txt  tags.csv

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file_path = '/content/drive/MyDrive/movielens/ml-32m/'

# %%
movies = pd.read_csv(file_path + 'movies.csv', sep=',')
print(type(movies))
movies.head(15)
# Out:
# <class 'pandas.core.frame.DataFrame'>
#     movieId                               title  \
# 0         1                    Toy Story (1995)
# 1         2                      Jumanji (1995)
# 2         3             Grumpier Old Men (1995)
# 3         4            Waiting to Exhale (1995)
# 4         5  Father of the Bride Part II (1995)
# 5         6                         Heat (1995)
# 6         7                      Sabrina (1995)
# 7         8                 Tom and Huck (1995)
# 8         9                 Sudden Death (1995)
# 9        10                    GoldenEye (1995)
# 10       11      American President, The (1995)
# 11       12  Dracula: Dead and Loving It (1995)
# 12       13                        Balto (1995)
# 13       14                        Nixon (1995)
# 14       15             Cutthroat Island (1995)
#
#                                          genres
# 0   Adventure|Animation|Children|Comedy|Fantasy
# 1                    Adventure|Children|Fantasy
# 2                                Comedy|Romance
# 3                          Comedy|Drama|Romance
# 4                                        Comedy
# 5                         Action|Crime|Thriller
# 6                                Comedy|Romance
# 7                            Adventure|Children
# 8                                        Action
# 9                     Action|Adventure|Thriller
# 10                         Comedy|Drama|Romance
# 11                                Comedy|Horror
# 12                 Adventure|Animation|Children
# 13                                        Drama
# 14                     Action|Adventure|Romance

# %%
tags = pd.read_csv('tags.csv', sep=',')
tags.head()
# Out:
#    userId  movieId          tag   timestamp
# 0      22    26479  Kevin Kline  1583038886
# 1      22    79592     misogyny  1581476297
# 2      22   247150   acrophobia  1622483469
# 3      34     2174        music  1249808064
# 4      34     2174        weird  1249808102

# %%
ratings = pd.read_csv('ratings.csv', sep=',', parse_dates=['timestamp'
])
ratings.head()
# Out:
# <ipython-input-24-a3bba7fcf552>:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   ratings = pd.read_csv('ratings.csv', sep=',', parse_dates=['timestamp'
#    userId  movieId  rating  timestamp
# 0       1       17     4.0  944249077
# 1       1       25     1.0  944250228
# 2       1       29     2.0  943230976
# 3       1       30     5.0  944249077
# 4       1       32     5.0  943228858

# %%
del ratings['timestamp']
del tags['timestamp']

# %%
row_0 = tags.iloc[0]
print(type(row_0))
print(row_0)
# Out:
# <class 'pandas.core.series.Series'>
# userId              22
# movieId          26479
# tag        Kevin Kline
# Name: 0, dtype: object

# %%
row_0.index
# Out:
# Index(['userId', 'movieId', 'tag'], dtype='object')

# %%
ratings.describe()
# Out:
#              userId       movieId        rating
# count  3.200020e+07  3.200020e+07  3.200020e+07
# mean   1.002785e+05  2.931861e+04  3.540396e+00
# std    5.794905e+04  5.095816e+04  1.058986e+00
# min    1.000000e+00  1.000000e+00  5.000000e-01
# 25%    5.005300e+04  1.233000e+03  3.000000e+00
# 50%    1.002970e+05  3.452000e+03  3.500000e+00
# 75%    1.504510e+05  4.419900e+04  4.000000e+00
# max    2.009480e+05  2.927570e+05  5.000000e+00

# %%
ratings.mode()
# Out:
#    userId  movieId  rating
# 0  175325      318     4.0

# %%
filter_2 = ratings.loc[ratings['rating'] > 0]

# %%
filter_2.groupby("movieId").mean()
# Out:
#                 userId    rating
# movieId
# 1        100369.803006  3.897438
# 2        100970.315423  3.275758
# 3        100388.785747  3.139447
# 4         97944.691732  2.845331
# 5        100427.174700  3.059602
# ...                ...       ...
# 292731    50685.000000  4.000000
# 292737   165364.000000  1.500000
# 292753   150812.000000  4.000000
# 292755    91097.000000  1.000000
# 292757   171418.000000  3.500000
#
# [84432 rows x 2 columns]

# %%
avg_ratings = ratings.groupby('movieId', as_index=False).mean()
del avg_ratings['userId']
avg_ratings.head()
# Out:
#    movieId    rating
# 0        1  3.897438
# 1        2  3.275758
# 2        3  3.139447
# 3        4  2.845331
# 4        5  3.059602

# %%
box_office = pd.merge(movies,avg_ratings, on='movieId', how='inner')
box_office.tail()
# Out:
#        movieId                       title                        genres  \
# 84427   292731   The Monroy Affaire (2022)                         Drama
# 84428   292737  Shelter in Solitude (2023)                  Comedy|Drama
# 84429   292753                 Orca (2023)                         Drama
# 84430   292755      The Angry Breed (1968)                         Drama
# 84431   292757   Race to the Summit (2023)  Action|Adventure|Documentary
#
#        rating
# 84427     4.0
# 84428     1.5
# 84429     4.0
# 84430     1.0
# 84431     3.5

# %%
is_highly_rated = box_office['rating'] >= 4.0
box_office[is_highly_rated].tail()
# Out:
#        movieId                              title       genres  rating
# 84417   292607  The Invention of the Other (2022)  Documentary     4.5
# 84418   292609   The Wind Blows the Border (2022)  Documentary     4.0
# 84419   292611                       Kenya (2022)  Documentary     4.0
# 84427   292731          The Monroy Affaire (2022)        Drama     4.0
# 84429   292753                        Orca (2023)        Drama     4.0

# %%
is_comedy = box_office['genres'].str.contains('Comedy')
box_office[is_comedy].head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
# 6        7                      Sabrina (1995)
#
#                                         genres    rating
# 0  Adventure|Animation|Children|Comedy|Fantasy  3.897438
# 2                               Comedy|Romance  3.139447
# 3                         Comedy|Drama|Romance  2.845331
# 4                                       Comedy  3.059602
# 6                               Comedy|Romance  3.363968

# %%
is_comedy
# Out:
# 0         True
# 1        False
# 2         True
# 3         True
# 4         True
#          ...
# 84427    False
# 84428     True
# 84429    False
# 84430    False
# 84431    False
# Name: genres, Length: 84432, dtype: bool

# %%
box_office[is_comedy & is_highly_rated].head()
# Out:
#      movieId                                        title  \
# 81        82              Antonia's Line (Antonia) (1995)
# 229      232  Eat Drink Man Woman (Yin shi nan nu) (1994)
# 292      296                          Pulp Fiction (1994)
# 351      356                          Forrest Gump (1994)
# 600      608                                 Fargo (1996)
#
#                           genres    rating
# 81                  Comedy|Drama  4.010176
# 229         Comedy|Drama|Romance  4.028991
# 292  Comedy|Crime|Drama|Thriller  4.196969
# 351     Comedy|Drama|Romance|War  4.052744
# 600  Comedy|Crime|Drama|Thriller  4.116533

# %%
box_office
# Out:
#        movieId                               title  \
# 0            1                    Toy Story (1995)
# 1            2                      Jumanji (1995)
# 2            3             Grumpier Old Men (1995)
# 3            4            Waiting to Exhale (1995)
# 4            5  Father of the Bride Part II (1995)
# ...        ...                                 ...
# 84427   292731           The Monroy Affaire (2022)
# 84428   292737          Shelter in Solitude (2023)
# 84429   292753                         Orca (2023)
# 84430   292755              The Angry Breed (1968)
# 84431   292757           Race to the Summit (2023)
#
#                                             genres    rating
# 0      Adventure|Animation|Children|Comedy|Fantasy  3.897438
# 1                       Adventure|Children|Fantasy  3.275758
# 2                                   Comedy|Romance  3.139447
# 3                             Comedy|Drama|Romance  2.845331
# 4                                           Comedy  3.059602
# ...                                            ...       ...
# 84427                                        Drama  4.000000
# 84428                                 Comedy|Drama  1.500000
# 84429                                        Drama  4.000000
# 84430                                        Drama  1.000000
# 84431                 Action|Adventure|Documentary  3.500000
#
# [84432 rows x 4 columns]
